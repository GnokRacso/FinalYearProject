# %% [markdown]
# <a href="https://colab.research.google.com/github/GnokRacso/FinalYearProject/blob/main/GatherData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#Agriculture -> https://drive.google.com/file/d/1ZBztt6cA-g_9ofUuWISKVt-Y-8mKbSb1/view?usp=sharing
#Info&Tech -> https://drive.google.com/file/d/1s8BTzP-vO5Gly2VHu5nP8LhZWzPCtnt4/view?usp=sharing
#Legal -> https://drive.google.com/file/d/1BUdaJNEL_G0wAi147UWQ7B2xGFHdd4Do/view?usp=sharing
#Manufacturing -> https://drive.google.com/file/d/1HCybYFwq-xNoFsj8ajWxGhKLQiyrtoDJ/view?usp=sharing
#Marketing -> https://drive.google.com/file/d/1DwIMuwJc2q4bYSqfZEBPMW1A1slqaOxE/view?usp=sharing
#Math_Sciences -> https://drive.google.com/file/d/1mjRW8M4MBTJjmgRnev8D8tpwvzaQj-yk/view?usp=sharing
#Policy & Socioeconomic -> https://drive.google.com/file/d/1FobZLU6OpeZaq3ugwegskTbK5SrbBKAd/view?usp=sharing
#Professional Services -> https://drive.google.com/file/d/1AuO6Kbw9p4el0gkIB97LU1SRwzRJBjYe/view?usp=sharing
#Tourism & Hospitality -> https://drive.google.com/file/d/12YdxE_VZif_5BArQ82DcQIkO4qVQTQD0/view?usp=sharing

AgriFile = drive.CreateFile({'id': '1ZBztt6cA-g_9ofUuWISKVt-Y-8mKbSb1'})
InfoTechFile = drive.CreateFile({'id': '1s8BTzP-vO5Gly2VHu5nP8LhZWzPCtnt4'})
LegalFile = drive.CreateFile({'id': '1BUdaJNEL_G0wAi147UWQ7B2xGFHdd4Do'})
ManuFile = drive.CreateFile({'id': '1HCybYFwq-xNoFsj8ajWxGhKLQiyrtoDJ'})
MarketFile = drive.CreateFile({'id': '1DwIMuwJc2q4bYSqfZEBPMW1A1slqaOxE'})
MathFile = drive.CreateFile({'id': '1mjRW8M4MBTJjmgRnev8D8tpwvzaQj-yk'})
PolicyFile = drive.CreateFile({'id': '1FobZLU6OpeZaq3ugwegskTbK5SrbBKAd'})
ProfessFile = drive.CreateFile({'id': '1AuO6Kbw9p4el0gkIB97LU1SRwzRJBjYe'})
TourismFile = drive.CreateFile({'id': '12YdxE_VZif_5BArQ82DcQIkO4qVQTQD0'})

# %%
AgriFile.GetContentFile('Agriculture.csv')
InfoTechFile.GetContentFile('Info&Tech.csv')
LegalFile.GetContentFile('Legal.csv')
ManuFile.GetContentFile('Manufacturing.csv')
MarketFile.GetContentFile('Marketing.csv')
MathFile.GetContentFile('Math_Sciences.csv')
PolicyFile.GetContentFile('Policy & Socioeconomic.csv')
ProfessFile.GetContentFile('Professional Services.csv')
TourismFile.GetContentFile('Tourism & Hospitality.csv')

# %%
import pandas as pd
agridata = pd.read_csv('Agriculture.csv')
infodata = pd.read_csv('Info&Tech.csv')
legaldata = pd.read_csv('Legal.csv')
manudata = pd.read_csv('Manufacturing.csv')
marketdata = pd.read_csv('Marketing.csv')
mathdata = pd.read_csv('Math_Sciences.csv')
policydata = pd.read_csv('Policy & Socioeconomic.csv')
professdata = pd.read_csv('Professional Services.csv')
tourismdata = pd.read_csv('Tourism & Hospitality.csv')

# %%
agridata.head()
# Out:
#                                                 Tech  ... pic
# 0    -Bioscience Technology\n-Advanced Materials\n    ... NaN
# 1  -Bioscience Technology\n-Advanced Materials\n      ... NaN
# 2  -Augmented analysis & data Discovery\n-Advance...  ... NaN
# 3     -Bioscience Technology\n-Advanced Materials\n   ... NaN
# 4  -Augmented analysis & data Discovery\n-Environ...  ... NaN
#
# [5 rows x 7 columns]

# %%
infodata.head()
# Out:
#                                                 Tech  ... pic
# 0  -Sensor Technology\n-Bioscience Technology\n-A...  ... NaN
#
# [1 rows x 7 columns]

# %%
legaldata.head()
# Out:
#                                                 Tech  ... pic
# 0  -augmented analysis & data discovery\n-advance...  ... NaN
#
# [1 rows x 7 columns]

# %%
manudata.head()
# Out:
#                                                 Tech  ... pic
# 0  Bioscience Technology\nAugmented analysis & da...  ... NaN
# 1  Augmented analysis & data discovery\nadvanced ...  ... NaN
# 2  Bioscience Technology\nAugmented analysis & da...  ... NaN
# 3  Bioscience Technology\nAugmented analysis & da...  ... NaN
# 4  Advanced Materials,\n Advanced Intelligence Sy...  ... NaN
#
# [5 rows x 7 columns]

# %%
marketdata.head()
# Out:
#                                                 Tech  ... pic
# 0  Augmented analysis & data discovery\nAdvance i...  ... NaN
# 1  Augmented analysis & data discovery\nAdvance i...  ... NaN
# 2  Augmented analysis & data discovery\nAdvance i...  ... NaN
# 3  Augmented analysis & data discovery\nAdvance i...  ... NaN
# 4  Augmented analysis & data discovery\nAdvance i...  ... NaN
#
# [5 rows x 7 columns]

# %%
mathdata.head()
# Out:
#                                                 Tech  ... pic
# 0  Augmented analysis & data discovery\nadvance m...  ... NaN
# 1  Augmented analysis & data discovery\nadvance m...  ... NaN
# 2  Augmented analysis & data discovery\nadvance m...  ... NaN
# 3  Augmented analysis & data discovery\nadvance m...  ... NaN
# 4  Augmented analysis & data discovery\nadvance m...  ... NaN
#
# [5 rows x 7 columns]

# %%
policydata.head()
# Out:
#                                             Category  ... pic
# 0  Advanced Intelligence Systems,\n Augmented Ana...  ... NaN
# 1  -Advance Intelligence System\n-Augmented Analy...  ... NaN
# 2  -Advance Intelligence System\nAugmented analys...  ... NaN
# 3  Advanced Intelligence Systems,\n Augmented Ana...  ... NaN
# 4  Augmented analysis & data discovery\nadvance m...  ... NaN
#
# [5 rows x 7 columns]

# %%
professdata.head()
# Out:
#                                                 Tech  ... pic
# 0  -Advance Intelligence System\n-blockchain\nAug...  ... NaN
# 1  Augmented Analyltics & Data discovery\nAdvance...  ... NaN
# 2  Augmented Analyltics & Data discovery\n-blockc...  ... NaN
# 3  -Augmented Analyltics & Data discovery\n-Cyber...  ... NaN
# 4  Augmented Analyltics & Data discovery\n-Blockc...  ... NaN
#
# [5 rows x 7 columns]

# %%
tourismdata.head()
# Out:
#                                          Tech Driver  ... pic
# 0       -Advance Intelligence System\nAdvanced model  ... NaN
# 1  Augmented Analyltics & Data discovery\nAdvance...  ... NaN
# 2  Augmented Analyltics & Data discovery\nAdvance...  ... NaN
# 3  Advanced Intelligence Systems, \nAugmented Ana...  ... NaN
# 4  Augmented Analyltics & Data discovery\nAdvance...  ... NaN
#
# [5 rows x 7 columns]
